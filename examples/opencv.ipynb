# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib notebook

from string_art import art

from matplotlib import pyplot as plt

# %%
n_hooks = 288
n_lines = 400
line_weight = 15
line_width = 1

# %%
image = art.prepare_image('lentach.jpg', invert=True)

lines = art.find_lines(image, n_hooks, n_lines, line_weight, line_width)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
n_hooks = 400
n_lines = 700
line_weight = 40
line_width = 2

# %%
image = art.prepare_image('style.jpg', invert=True)

# %%
hooks = art.get_hooks(n_hooks, *image.shape)

pixel_paths = art.all_pixel_paths(hooks)

# %%
image_opt, lines = art.optimize(image, n_lines, hooks, pixel_paths,
                                line_weight=line_weight, line_width=line_width,
                                min_loss=-50000,
                                show_plots=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
lines
# Out:
# [(317, 153),
#  (161, 372),
#  (165, 388),
#  (164, 389),
#  (382, 158),
#  (371, 162),
#  (281, 24),
#  (375, 160),
#  (185, 370),
#  (14, 141),
#  (374, 154),
#  (7, 138),
#  (348, 164),
#  (376, 159),
#  (318, 152),
#  (253, 53),
#  (320, 151),
#  (143, 376),
#  (360, 130),
#  (192, 364),
#  (321, 150),
#  (160, 373),
#  (159, 380),
#  (177, 333),
#  (359, 131),
#  (316, 155),
#  (165, 347),
#  (148, 322),
#  (5, 144),
#  (149, 354),
#  (350, 163),
#  (141, 377),
#  (356, 148),
#  (156, 315),
#  (365, 161),
#  (335, 176),
#  (369, 164),
#  (54, 252),
#  (142, 6),
#  (140, 16),
#  (3, 145),
#  (323, 147),
#  (10, 137),
#  (140, 378),
#  (365, 191),
#  (145, 375),
#  (173, 336),
#  (286, 26),
#  (353, 150),
#  (24, 282),
#  (166, 346),
#  (250, 51),
#  (146, 374),
#  (147, 366),
#  (254, 50),
#  (338, 167),
#  (329, 178),
#  (24, 287),
#  (382, 139),
#  (161, 390),
#  (251, 55),
#  (339, 166),
#  (50, 249),
#  (26, 284),
#  (363, 193),
#  (151, 352),
#  (349, 164),
#  (324, 146),
# ...
