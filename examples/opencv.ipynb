# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib notebook

from string_art import art

from matplotlib import pyplot as plt

# %%
n_hooks = 400
n_lines = 2000

optimizer_params = {
    'line_weight': 15,
    'line_width': 2,
    'min_loss': -50000,
    'show_progress': True
}

loss_params = {
    'line_norm': 'length'
}

# %%
image = art.prepare_image('ira3.png', invert=True, high_contrast=False)

# %%
lines = art.find_lines(
    image, n_hooks, n_lines, 
    optimizer_params, loss_params)
# Out:
# [87, 113, 87, 113] 0.7841726618705036
# (556, 436)
# <img src="data:image/png;base64,..." width="600">

# %%
n_hooks = 300
n_lines = 2000

optimizer_params = {
    'line_weight': 15,
    'line_width': 1,
    'min_loss': -50000,
    'show_progress': True
}

loss_params = {
    'line_norm': 'length'
}

# %%
image = art.prepare_image('style3.jpg', invert=True, high_contrast=False)

# %%
# import cv2
# import numpy as np

# edges = cv2.Canny(image, 180, 200)
# edges = cv2.dilate(edges, np.ones((1, 1)))

# plt.figure()
# plt.imshow(np.clip(image.astype(int) + edges.astype(int), 0, 255), cmap=plt.cm.gray)
# image = np.clip(image.astype(int) + edges.astype(int), 0, 255).astype(np.uint8)

# %%
# plt.figure()
# plt.imshow(image)

# %%
lines = art.find_lines(
    image, n_hooks, n_lines, 
    optimizer_params, loss_params)
# Out:
# [67, 83, 67, 83] 0.8090452261306532
# (199, 161)
# <img src="data:image/png;base64,..." width="600">

# %%
hooks = art.get_hooks(n_hooks, *image.shape)
thread_length = art.thread_length(lines, hooks)

print("Thread length: %f meters" % art.pixel_to_meters(thread_length, image.shape, (0.26, 0.32)))
# Out:
# Thread length: 732.144223 meters
