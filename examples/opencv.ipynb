# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib notebook

from string_art import art

from matplotlib import pyplot as plt

# %%
n_hooks = 400
n_lines = 1000
line_weight = 15
line_width = 2

# %%
image = art.prepare_image('style4.jpg', invert=True)

# %%
lines = art.find_lines(image, n_hooks, n_lines, 
                       line_weight=line_weight, line_width=line_width,
                       min_loss=-50000, norm='none',
                       show_progress=True)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
# count number of threads
from collections import Counter
from itertools import chain

hooks_flatten = list(chain(*lines))

# %%
counter = Counter(hooks_flatten)

# %%
max(counter.items(), key=lambda x: x[1])
# Out:
# (456, 8)
